# %% [markdown]
# # **Regression**
#
# **Regression** is a statistical method used in finance, investing, and other disciplines that attempts to determine the strength and character of the relationship between one dependent variable (usually denoted by Y) and a series of other variables (known as independent variables).
#
# **Correlation** is a statistical measure that expresses the extent to which two variables are linearly related (meaning they change together at a constant rate).
#
# ***If there's no correlation there can't be any Regression then***

# %% [markdown]
# # **Simple Linear Regression**
#
# Consider the model function
#
# ***y = α + βx***
# or
# ***y = mx +c***
#
# which describes a line with slope β and y-intercept α. In general such a relationship may not hold exactly for the largely unobserved population of values of the independent and dependent variables; we call the unobserved deviations from the above equation the errors.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Linear_regression.svg/1280px-Linear_regression.svg.png">
#
#
# Here on obvoius fact, y is a dependent variable and x is an independant variable.

# %% [markdown]
# ## **Residual**
#
# ***residual = actualvalue - estimatedvalue***
#
# or
#
# ***e = y - ŷ***
#
# Residual is the difference between actual value and estimated value.
#
# <img src = "https://i.stack.imgur.com/wY8e5.png">

# %% [markdown]
# ### **Where is Linear Regression used?**
#
#
# *   Evaluating Trends and Sales Estimates
# *   Analyzing the Impact of Price Changes
# *   Assessment of risk in financial services and insurance domain

# %% [markdown]
# ## **Simple Linear Regression Algorithm**
#
# Mathematical Intuition
#
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## **Getting Started with Linear Regression**

# %%
#importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import math

# %% [markdown]
# ## **DataFraming**
#
# Read .csv data into a DataFrame

# %%
dataset = pd.read_csv("headbrain.csv")
dataset.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
size = dataset['Head Size(cm^3)']
weight = dataset['Brain Weight(grams)']

print(size)
print(weight)
# Out:
# 0      4512
# 1      3738
# 2      4261
# 3      3777
# 4      4177
#        ...
# 232    3214
# 233    3394
# 234    3233
# 235    3352
# 236    3391
# Name: Head Size(cm^3), Length: 237, dtype: int64
# 0      1530
# 1      1297
# 2      1335
# 3      1282
# 4      1590
#        ...
# 232    1110
# 233    1215
# 234    1104
# 235    1170
# 236    1120
# Name: Brain Weight(grams), Length: 237, dtype: int64

# %% [markdown]
# ## **Visualizing Dataset**

# %%
plt.scatter(size, weight)
plt.show()

# %% [markdown]
# ## **Converting dataframes into NumPy Arrays**
# Machine Learning handle arrays not dataframes (it's now neccessary but numpy arrays are better than in machine learning )

# %%
size.shape, weight.shape
# Out:
# ((237,), (237,))

# %%
dataset.columns
# Out:
# Index(['Gender', 'Age Range', 'Head Size(cm^3)', 'Brain Weight(grams)'], dtype='object')

# %%
X = np.array(size).reshape(-1,1)
y = np.array(weight).reshape(-1,1)

# %%
X.shape, y.shape
# Out:
# ((237, 1), (237, 1))

# %% [markdown]
# ## **Training the Model**
# We are using Linear regression model as imported from sklearn library and then it's being trained on x and y (any 2 major axis of datasets)

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## **Mean Sqaured Error & R - Squared Value**
#
# The **mean squared error** or mean squared deviation of an estimator measures the average of the squares of the errors—that is, the average squared difference between the estimated values and the actual value. MSE is a risk function, corresponding to the expected value of the squared error loss.
#
# The **coefficient of determination**, denoted R² or r² and pronounced "R squared", is the proportion of the variance in the dependent variable that is predictable from the independent variable.
#
# <img src="https://miro.medium.com/max/1432/1*w3MdmyJ2bgnezao1liJcDA.png">

# %%
regression_model_mse = mean_squared_error(X,y)
print('Mean Squared Error:\t',math.sqrt(regression_model_mse))
print("R squared value\t\t",model.score(X,y))
# Out:
# Mean Squared Error:	 2367.495611943946
# R squared value		 0.639311719957

# %%
print(model.coef_[0])
print(model.intercept_[0])
# Out:
# [0.26342934]
# 325.5734210494426

# %% [markdown]
# ## **Visualization**
#
# Visualize the dataset with the fit model using matplotlib.

# %%
plt.scatter(X,y, color = 'orange')
plt.plot(X,model.predict(X), color = 'black')
plt.title('Linear Regression')
plt.xlabel('Head Size')
plt.ylabel('Brain Weight')
# Out:
# Text(0, 0.5, 'Brain Weight')

# %% [markdown]
# ## **Prediction**
# We will predict the Brain weight by giving an input of Brain Size

# %%
print('Prediction by the model:\t', model.predict([[2000]]))
# Out:
# Prediction by the model:	 [[852.43210003]]

# %% [markdown]
# ### Linear Regression using TensorFlow

# %%
## Test
np.array(dataset["Head Size(cm^3)"]).reshape(-1, 1).shape
# Out:
# (237, 1)

# %%
X.shape,y.shape
# Out:
# ((237, 1), (237, 1))

# %%
import tensorflow as tf 
from tensorflow.keras.layers import Dense as tf_dense
from tensorflow.keras import Sequential as tf_sequential

# %%
model = tf_sequential()
model.add(tf_dense(1))
model.compile(optimizer="adam", loss="mean_squared_error")
model.fit(X,y, epochs=30)
# Out:
# Epoch 1/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1015939.0625
# Epoch 2/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 947872.8750
# Epoch 3/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 895281.1250
# Epoch 4/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 837863.0625
# Epoch 5/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 793162.2500
# Epoch 6/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 736544.3750
# Epoch 7/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 691312.9375
# Epoch 8/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 645290.8750
# Epoch 9/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 606947.0625
# Epoch 10/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 561561.3125
# Epoch 11/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 529614.5000
# Epoch 12/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 501036.9688
# Epoch 13/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 454551.6250
# Epoch 14/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 435788.2188
# Epoch 15/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 401821.5625
# Epoch 16/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 363905.1875
# Epoch 17/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 338167.2812
# Epoch 18/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 322401.7812
# Epoch 19/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 301194.8125
# Epoch 20/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 272108.6250
# Epoch 21/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 243807.9844
# Epoch 22/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 229882.2812
# Epoch 23/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 214752.0000
# Epoch 24/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 203117.1719
# Epoch 25/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 178440.4688
# Epoch 26/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 166635.2812
# Epoch 27/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 150854.5000
# Epoch 28/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 137542.6562
# Epoch 29/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126689.7812
# Epoch 30/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 115172.4688

# %%
print('Prediction by the model:\t', model.predict(np.array([[2000]])))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Prediction by the model:	 [[528.85114]]

# %% [markdown]
# ####
